# %% [markdown]
# #### Import required libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Load dataset

# %%
data=pd.read_csv("data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #### Label Encode the output

# %% [markdown]
# This makes the diagnosis M: 1 and B:0

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data.diagnosis=le.fit_transform(data.diagnosis)
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #### Remove unnecessary features

# %%
data = data.drop(["id","Unnamed: 32"],axis=1)

# %%
y=data.diagnosis
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %%
x=data.drop("diagnosis",axis=1)
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean           ...             radius_worst  \
# ...

# %% [markdown]
# #### Standardization

# %%
x = (x - x.mean()) / (x.std())

# %% [markdown]
# #### Import machine learning models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Stacked Model

# %% [markdown]
# Split the dataset

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(x, y, test_size=0.30, random_state=0)

# %% [markdown]
# Random forest model

# %% [markdown]
# Creating a new dataset with predictions from the random forest model

# %%
X = np.zeros((X_validation.shape[0],31))
X.shape
X[:,0:30]=X_validation

# %%
rf=RandomForestClassifier(random_state=3)
rf.fit(X_train, Y_train)
predictions = rf.predict(X_validation)
X[:,30]=predictions
print(accuracy_score(Y_validation, predictions))
# Out:
# 0.988304093567

# %% [markdown]
# Split the new dataset

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y_validation, test_size=0.30, random_state=0)

# %% [markdown]
# Logistic regression model

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
predictions = lr.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
# Out:
# 0.980769230769

# %% [markdown]
# #### Stacked model using train, cross validation and test datasets

# %% [markdown]
# Split the dataset into 3, train, validation and test

# %%
X_train, X_other, y_train, y_other = train_test_split(x, y, test_size=0.4, random_state=0)
X_cv, X_test, y_cv, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=0)

# %%
X = np.zeros((X_cv.shape[0],31))
X.shape
X[:,0:30]=X_cv

# %% [markdown]
# Random forest model

# %% [markdown]
# creating random forest models with different random_state s

# %%
l=[]
for i in range(100):
    print(i)
    rf=RandomForestClassifier(random_state=i)
    l.append(rf)
    rf.fit(X_train, y_train)
    predictions = rf.predict(X_cv)
    print(accuracy_score(y_train, rf.predict(X_train)))
    print(accuracy_score(y_cv, predictions))
# Out:
# 0
# 1.0
# 0.947368421053
# 1
# 0.991202346041
# 0.973684210526
# 2
# 0.991202346041
# 0.982456140351
# 3
# 0.994134897361
# 0.964912280702
# 4
# 0.99706744868
# 0.938596491228
# 5
# 0.99706744868
# 0.938596491228
# 6
# 0.99706744868
# 0.938596491228
# 7
# 0.99706744868
# 0.947368421053
# 8
# 0.99706744868
# 0.964912280702
# 9
# 0.988269794721
# 0.956140350877
# 10
# 0.991202346041
# 0.947368421053
# 11
# 0.991202346041
# 0.938596491228
# 12
# 0.99706744868
# 0.938596491228
# 13
# 0.994134897361
# 0.973684210526
# 14
# 0.994134897361
# 0.947368421053
# 15
# 1.0
# 0.973684210526
# 16
# 1.0
# 0.964912280702
# 17
# 1.0
# 0.947368421053
# 18
# 0.99706744868
# 0.947368421053
# 19
# 1.0
# 0.964912280702
# 20
# 0.991202346041
# 0.938596491228
# 21
# 0.994134897361
# 0.938596491228
# 22
# 1.0
# 0.964912280702
# 23
# 0.99706744868
# 0.956140350877
# 24
# 0.99706744868
# 0.947368421053
# 25
# 1.0
# 0.956140350877
# 26
# 0.99706744868
# 0.964912280702
# 27
# 0.99706744868
# 0.973684210526
# 28
# ...

# %% [markdown]
# Random state = 97 gives highest cross validation accuracy, so creating a new dataset with the predictions from this random forest model

# %%
predictions = l[97].predict(X_cv)
print(accuracy_score(y_train, l[97].predict(X_train)))
print(accuracy_score(y_cv, predictions))
X[:,30]=predictions
print(accuracy_score(y_test, l[97].predict(X_test)))
# Out:
# 0.99706744868
# 0.982456140351
# 0.973684210526

# %% [markdown]
# Split the new dataset into 3

# %%
X_train, X_other, y_train, y_other = train_test_split(X, y_cv, test_size=0.4, random_state=0)
X_cv, X_test, y_cv, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=0)

# %% [markdown]
# Logistic Regression model

# %% [markdown]
# Creating logistic regression models with different C

# %%
l=[1/0.0001,1/0.0003, 1/0.001, 1/0.003, 1/0.01, 1/0.03, 1/0.1, 1/0.3, 1, 1/3, 1/10]
l2=[]
for i in range (11):
    print(l[i])
    lr = LogisticRegression(C=l[i])
    l2.append(lr)
    lr.fit(X_train, y_train)
    predictions = lr.predict(X_cv)
    print(accuracy_score(y_train, lr.predict(X_train)))
    print(accuracy_score(y_cv, predictions))
    print()
# Out:
# 10000.0
# 1.0
# 0.95652173913
#
# 3333.3333333333335
# 1.0
# 0.95652173913
#
# 1000.0
# 1.0
# 1.0
#
# 333.3333333333333
# 1.0
# 1.0
#
# 100.0
# 1.0
# 1.0
#
# 33.333333333333336
# 1.0
# 1.0
#
# 10.0
# 1.0
# 1.0
#
# 3.3333333333333335
# 1.0
# 1.0
#
# 1
# 1.0
# 1.0
#
# 0.3333333333333333
# 1.0
# 0.95652173913
#
# 0.1
# 1.0
# 0.95652173913

# %% [markdown]
# C= 1/0.003, 1/0.01, 1/0.03, 1/0.1, 1/0.3, 1   give highest validation accuracy, so testing these models with the test dataset

# %%
for i in range (3,9):
    print(l[i])
    lr=l2[i]
    predictions = lr.predict(X_cv)
    print(accuracy_score(y_train, lr.predict(X_train)))
    print(accuracy_score(y_cv, predictions))
    print(accuracy_score(y_test, l2[9].predict(X_test)))
    print()
# Out:
# 333.3333333333333
# 1.0
# 1.0
# 1.0
#
# 100.0
# 1.0
# 1.0
# 1.0
#
# 33.333333333333336
# 1.0
# 1.0
# 1.0
#
# 10.0
# 1.0
# 1.0
# 1.0
#
# 3.3333333333333335
# 1.0
# 1.0
# 1.0
#
# 1
# 1.0
# 1.0
# 1.0

# %% [markdown]
# Accuracy on test dataset=1.
