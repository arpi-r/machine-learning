# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("data.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data.diagnosis=le.fit_transform(data.diagnosis)
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data = data.drop(["id","Unnamed: 32"],axis=1)

# %%
y=data.diagnosis
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %%
X=data.drop("diagnosis",axis=1)
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean           ...             radius_worst  \
# ...

# %%
X = (X - X.mean()) / (X.std())

# %%
from scipy import optimize

# %%
def predict(Theta1, Theta2, X):
    m = X.shape[0]
    num_labels = Theta2.shape[0]
    p = np.zeros(m)
    h1 = sigmoid(np.dot(np.concatenate([np.ones((m, 1)), X], axis=1), Theta1.T))
    h2 = sigmoid(np.dot(np.concatenate([np.ones((m, 1)), h1], axis=1), Theta2.T))
    p = np.argmax(h2, axis=1)
    for i in range(h2.size):
        if(h2[i]<0.5):
            p[i]=0
        else:
            p[i]=1
    return p


def debugInitializeWeights(fan_out, fan_in):
    # Initialize W using "sin". This ensures that W is always of the same values and will be
    # useful for debugging
    W = np.sin(np.arange(1, 1 + (1+fan_in)*fan_out))/10.0
    W = W.reshape(fan_out, 1+fan_in, order='F')
    return W


def computeNumericalGradient(J, theta, e=1e-4):
    numgrad = np.zeros(theta.shape)
    perturb = np.diag(e * np.ones(theta.shape))
    for i in range(theta.size):
        loss1, _ = J(theta - perturb[:, i])
        loss2, _ = J(theta + perturb[:, i])
        numgrad[i] = (loss2 - loss1)/(2*e)
    return numgrad


def checkNNGradients(nnCostFunction, lambda_=0):
    input_layer_size = 3
    hidden_layer_size = 5
    num_labels = 3
    m = 5

    # We generate some 'random' test data
    Theta1 = debugInitializeWeights(hidden_layer_size, input_layer_size)
    Theta2 = debugInitializeWeights(num_labels, hidden_layer_size)

    # Reusing debugInitializeWeights to generate X
    X = debugInitializeWeights(m, input_layer_size - 1)
    y = np.arange(1, 1+m) % num_labels
    # Unroll parameters
    nn_params = np.concatenate([Theta1.ravel(), Theta2.ravel()])

    # short hand for cost function
    costFunc = lambda p: nnCostFunction(p, input_layer_size, hidden_layer_size,
                                        num_labels, X, y, lambda_)
    cost, grad = costFunc(nn_params)
    numgrad = computeNumericalGradient(costFunc, nn_params)

    # Visually examine the two gradient computations.The two columns you get should be very similar.
    print(np.stack([numgrad, grad], axis=1))
    print('The above two columns you get should be very similar.')
    print('(Left-Your Numerical Gradient, Right-Analytical Gradient)\n')

    # Evaluate the norm of the difference between two the solutions. If you have a correct
    # implementation, and assuming you used e = 0.0001 in computeNumericalGradient, then diff
    # should be less than 1e-9.
    diff = np.linalg.norm(numgrad - grad)/np.linalg.norm(numgrad + grad)

    print('If your backpropagation implementation is correct, then \n'
          'the relative difference will be small (less than 1e-9). \n'
          'Relative Difference: %g' % diff)


def sigmoid(z):
    return 1.0 / (1.0 + np.exp(-z))

# %%
input_layer_size  = 30 # 30 input features
hidden_layer_size = 50   # 50 hidden units
num_labels = 1          # 1 label, 0: B, 1: M

# %%
def nnCostFunction(nn_params,
                   input_layer_size,
                   hidden_layer_size,
                   num_labels,
                   X, y, lambda_=0.0):
  
    # Reshape nn_params back into the parameters Theta1 and Theta2, the weight matrices
    # for our 2 layer neural network
    Theta1 = np.reshape(nn_params[:hidden_layer_size * (input_layer_size + 1)],
                        (hidden_layer_size, (input_layer_size + 1)))

    Theta2 = np.reshape(nn_params[(hidden_layer_size * (input_layer_size + 1)):],
                        (num_labels, (hidden_layer_size + 1)))

    m = y.size
         
    J = 0
    Theta1_grad = np.zeros(Theta1.shape)
    Theta2_grad = np.zeros(Theta2.shape)

    h = np.zeros(m,)
    X = np.concatenate([np.ones((m, 1)), X], axis=1)
    del1=0
    del2=0
    k=num_labels
    #ny=np.zeros([m,k])
    #nh=np.zeros([m,k])
    for i in range(m):
        a1 = X[i][:,None] 
        z2=np.dot(Theta1,a1)
        a2=sigmoid(z2)
        a2 = np.vstack((np.ones(1),a2))
        z3=np.dot(Theta2,a2)
        h=sigmoid(z3)
        t=int(y[i])
        #ny[i,t]=1
        c=(np.sum(-(np.multiply(int(y[i]),np.log(h)))-(np.multiply((1-int(y[i])),np.log(1-h)))))/m
        J=J+c
        
        d3=h-y[i]
        d2=np.dot(np.transpose(Theta2),d3) 
        d2=d2[1:] * sigmoidGradient(z2)
        del2=del2+ np.dot(d3,np.transpose(a2))
        del1=del1+ np.dot(d2,np.transpose(a1))
        
    t1=np.sum(np.square(Theta1[:,1:]))
    t2=np.sum(np.square(Theta2[:,1:]))
    reg=lambda_ * (t1+t2) / (2*m) 
    J=J+reg
    Theta1_grad[:,1:] = del1[:,1:]/m + lambda_ * (Theta1[:,1:]) /m
    Theta2_grad[:,1:] = del2[:,1:]/m + lambda_ * (Theta2[:,1:]) /m 
    Theta1_grad[:,0] = del1[:,0]/m
    Theta2_grad[:,0] = del2[:,0]/m   
    
    grad = np.concatenate([Theta1_grad.ravel(), Theta2_grad.ravel()])

    return J, grad

# %%
def sigmoidGradient(z):

    g = np.zeros(z.shape)
    s=sigmoid(z)
    g= s * ( 1-s )

    return g

# %%
def randInitializeWeights(L_in, L_out, epsilon_init=0.12):
    W = np.zeros((L_out, 1 + L_in))
    W = ( np.random.rand(L_out, 1 + L_in) * 2 * epsilon_init )- epsilon_init
    return W

# %%
print('Initializing Neural Network Parameters ...')

initial_Theta1 = randInitializeWeights(input_layer_size, hidden_layer_size)
initial_Theta2 = randInitializeWeights(hidden_layer_size, num_labels)

# Unroll parameters
initial_nn_params = np.concatenate([initial_Theta1.ravel(), initial_Theta2.ravel()], axis=0)
# Out:
# Initializing Neural Network Parameters ...

# %%
checkNNGradients(nnCostFunction)
# Out:
# [[  3.43305339e-02   3.43305339e-02]
#  [ -1.03650053e-04  -1.03650054e-04]
#  [ -2.70371281e-04  -2.70371281e-04]
#  [ -4.97381647e-05  -4.97381632e-05]
#  [ -3.54624087e-02  -3.54624088e-02]
#  [  1.09126705e-04   1.09126706e-04]
#  [  2.78554946e-04   2.78554942e-04]
#  [  4.89043006e-05   4.89043008e-05]
#  [  3.59666699e-02   3.59666700e-02]
#  [ -1.08973723e-04  -1.08973722e-04]
#  [ -2.80373400e-04  -2.80373401e-04]
#  [ -5.00889419e-05  -5.00889415e-05]
#  [ -3.56315097e-02  -3.56315097e-02]
#  [  1.06344376e-04   1.06344374e-04]
#  [  2.75486844e-04   2.75486843e-04]
#  [  4.99460251e-05   4.99460259e-05]
#  [  3.46022158e-02   3.46022158e-02]
#  [ -1.05294569e-04  -1.05294567e-04]
#  [ -2.66808340e-04  -2.66808341e-04]
#  [ -4.60723082e-05  -4.60723071e-05]
#  [ -6.85455030e-01  -6.85455030e-01]
#  [ -3.57299008e-01  -3.57299008e-01]
#  [ -3.58362745e-01  -3.58362745e-01]
#  [ -3.45054729e-01  -3.45054729e-01]
#  [ -3.29602515e-01  -3.29602515e-01]
# ...

# %%
#  Check gradients by running checkNNGradients
lambda_ = 3
checkNNGradients(nnCostFunction, lambda_)
# Out:
# [[ 0.03433053  0.03433053]
#  [-0.01686858 -0.01686858]
#  [-0.06026978 -0.06026978]
#  [-0.01732394 -0.01732394]
#  [-0.03546241 -0.03546241]
#  [ 0.03952832  0.03952832]
#  [-0.03191582 -0.03191582]
#  [-0.05763495 -0.05763495]
#  [ 0.03596667  0.03596667]
#  [ 0.05925252  0.05925252]
#  [ 0.02492965  0.02492965]
#  [-0.04510932 -0.04510932]
#  [-0.03563151 -0.03563151]
#  [ 0.02483345  0.02483345]
#  [ 0.05971193  0.05971193]
#  [ 0.00904258  0.00904258]
#  [ 0.03460222  0.03460222]
#  [-0.03274656 -0.03274656]
#  [ 0.03875046  0.03875046]
#  [ 0.05473064  0.05473064]
#  [-0.68545503 -0.68545503]
#  [-0.40270716 -0.40270716]
#  [-0.31894355 -0.31894355]
#  [-0.377696   -0.377696  ]
#  [-0.30439249 -0.30439249]
#  [-0.3434974  -0.3434974 ]
#  [-0.68894341 -0.68894341]
#  [-0.4166495  -0.4166495 ]
#  [-0.30082273 -0.30082273]
#  [-0.40681103 -0.40681103]
#  [-0.27184667 -0.27184667]
#  [-0.38556986 -0.38556986]
#  [-0.7025993  -0.7025993 ]
#  [-0.38298421 -0.38298421]
# ...

# %%
options= {'maxiter': 200}

lambda_ = 0.5

# Create "short hand" for the cost function to be minimized
costFunction = lambda p: nnCostFunction(p, input_layer_size,
                                        hidden_layer_size,
                                        num_labels, X, y, lambda_)

# Now, costFunction is a function that takes in only one argument
# (the neural network parameters)
res = optimize.minimize(costFunction,
                        initial_nn_params,
                        jac=True,
                        method='TNC',
                        options=options)

# get the solution of the optimization
nn_params = res.x
        
# Obtain Theta1 and Theta2 back from nn_params
Theta1 = np.reshape(nn_params[:hidden_layer_size * (input_layer_size + 1)],
                    (hidden_layer_size, (input_layer_size + 1)))

Theta2 = np.reshape(nn_params[(hidden_layer_size * (input_layer_size + 1)):],
                    (num_labels, (hidden_layer_size + 1)))

# %%
pred = predict(Theta1, Theta2, X)
print('Training Set Accuracy: %f' % (np.mean(pred == y) * 100))
# Out:
# Training Set Accuracy: 99.297012

# %%
# modified exercise 4 for neural network

# %%
#neural networks using scikit learn

# %%
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.model_selection import train_test_split
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size=0.4, random_state=42)
X_cv, X_test, y_cv, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=42)

# %%
l=[0,0.0001,0.0003, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10]
l2=[]

for i in range(12):
    mlp=  MLPClassifier(hidden_layer_sizes=(50,), max_iter=200, alpha=l[i],
                    solver='sgd', verbose=0, tol=1e-4, random_state=1,
                    learning_rate_init=.1)

    mlp.fit(X_train, y_train)
    l2.append(mlp)
    print(l[i],"\t\t",  mlp.score(X_train, y_train), "\t\t" , mlp.score(X_cv, y_cv))
# Out:
# 0 		 1.0 		 0.982456140351
# 0.0001 		 1.0 		 0.982456140351
# 0.0003 		 1.0 		 0.982456140351
# 0.001 		 1.0 		 0.982456140351
# 0.003 		 1.0 		 0.982456140351
# 0.01 		 1.0 		 0.982456140351
# 0.03 		 1.0 		 0.982456140351
# 0.1 		 1.0 		 0.982456140351
# 0.3 		 1.0 		 0.982456140351
# 1 		 0.991202346041 		 0.982456140351
# 3 		 0.985337243402 		 0.991228070175
# 10 		 0.976539589443 		 0.991228070175

# %%
# accuracy on test set for alpha with highest accuracy on cross validation set 
for i in range(10,12):
    print(l[i],"\t",  l2[i].score(X_test, y_test))
# Out:
# 3 	 0.982456140351
# 10 	 0.982456140351

# %%
# highest accuracy in test and cross validation set is for c=3 and c=10

# Test and validation accuracy are higher than test accuracy
